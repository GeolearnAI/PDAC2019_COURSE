# %% [markdown]
# # CONCEPTS AND APPLICATION OF MACHINE LEARNING TO MINING GEOSCIENCE: A PRACTICAL COURSE
#
# ## Welcome to section 5 exercise
#
# - This page is called a jupyter notebook. Project Jupyter exists to develop open-source software, open-standards, and services for interactive computing across dozens of programming languages. Here we execute Python 3x.
#
# - In order to complete this exercise, you do not require any prior programming skills. The idea is to let the student change variables and execute functions to get an idea of the workflow to train a Convolutional Neural Network (CNN)

# %% [markdown]
# # 1. Import librairy with functions and set-up Data directory path and make sure the project is pointing to the data (LEM-37 and LEM-18 directories)
# Ex: C:\Documents\path_to_data

# %%
import geolearn_funcs
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # User intervention required
# Fill the data path

# %%
DATA_DIR = '/Users/loren/Desktop/EXAMPLE_DATA/'

# %% [markdown]
# **Make sure set-up is ok**

# %%
geolearn_funcs.set_up_project(DATA_DIR)
# Out:
# Project setup OK

# %% [markdown]
# #### If you have the mention 'Project setup is ok', congratulations you are ready to start working. If not please check your data path or raise your hand

# %% [markdown]
# # 2. Check the core pictures and their labels to make sure everything is in order

# %% [markdown]
# ### Displaying examples from the training set

# %%
geolearn_funcs.plot_examples(DATA_DIR,train=True)

# %% [markdown]
# ### Displaying distribution of labels from the training set

# %%
geolearn_funcs.plot_histogram(DATA_DIR,train=True)

# %% [markdown]
# ### Displaying examples from the validation set

# %%
geolearn_funcs.plot_examples(DATA_DIR,train=False)

# %% [markdown]
# ### Displaying distribution of labels from the validation set

# %%
geolearn_funcs.plot_histogram(DATA_DIR,train=False)

# %% [markdown]
# # 3. Build a first simple model

# %% [markdown]
# # User intervention possible
# Change the variables to build the model

# %%
MODEL_TYPE = 'legend' #'simple' or 'legend'
TARGET_SHAPE = (200,40,3)

# %% [markdown]
# #### Build the model according to defined variables

# %%
cnn = geolearn_funcs.build_model(MODEL_TYPE,TARGET_SHAPE)

# %% [markdown]
# #### Display the model layers

# %%
cnn.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 200, 40, 3)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 200, 40, 16)       448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 200, 40, 16)       64
# _________________________________________________________________
# activation_1 (Activation)    (None, 200, 40, 16)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 100, 20, 16)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 100, 20, 32)       4640
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 100, 20, 32)       128
# _________________________________________________________________
# activation_2 (Activation)    (None, 100, 20, 32)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 100, 20, 32)       9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 100, 20, 32)       128
# _________________________________________________________________
# activation_3 (Activation)    (None, 100, 20, 32)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 20, 32)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 50, 10, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 50, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 50, 10, 64)        256
# _________________________________________________________________
# activation_4 (Activation)    (None, 50, 10, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 50, 10, 64)        36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 50, 10, 64)        256
# _________________________________________________________________
# activation_5 (Activation)    (None, 50, 10, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 50, 10, 64)        36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 50, 10, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 50, 10, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50, 10, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 32000)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2048064
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# activation_7 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# _________________________________________________________________
# activation_8 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 2,156,421
# Trainable params: 2,155,749
# Non-trainable params: 672
# _________________________________________________________________

# %%
geolearn_funcs.plot_examples(DATA_DIR,train=True,prediction=True,model=cnn)

# %% [markdown]
# # 4. Start training your model

# %%
EPOCHS = 10

# %%
geolearn_funcs.train_model(DATA_DIR,cnn,EPOCHS)
# Out:
# Epoch 1/10
# 1090/1090 [==============================] - 29s 27ms/step - loss: 1.1822 - acc: 0.5906 - val_loss: 0.9873 - val_acc: 0.7526
# Epoch 2/10
# 1090/1090 [==============================] - 29s 27ms/step - loss: 1.1476 - acc: 0.5987 - val_loss: 0.9491 - val_acc: 0.7526
# Epoch 3/10
# 1090/1090 [==============================] - 29s 27ms/step - loss: 1.1400 - acc: 0.5992 - val_loss: 0.9636 - val_acc: 0.7526
# Epoch 4/10
# 1090/1090 [==============================] - 29s 26ms/step - loss: 1.1317 - acc: 0.6002 - val_loss: 0.9423 - val_acc: 0.7526
# Epoch 5/10
# 1090/1090 [==============================] - 29s 26ms/step - loss: 1.1259 - acc: 0.6002 - val_loss: 1.0042 - val_acc: 0.7526
# Epoch 6/10
# 1090/1090 [==============================] - 29s 26ms/step - loss: 1.1250 - acc: 0.6001 - val_loss: 0.9254 - val_acc: 0.7526
# Epoch 7/10
# 1090/1090 [==============================] - 29s 27ms/step - loss: 1.1247 - acc: 0.6002 - val_loss: 0.9465 - val_acc: 0.7522
# Epoch 8/10
# 1090/1090 [==============================] - 30s 27ms/step - loss: 1.1163 - acc: 0.6002 - val_loss: 0.9405 - val_acc: 0.7526
# Epoch 9/10
# 1090/1090 [==============================] - 29s 27ms/step - loss: 1.1181 - acc: 0.6002 - val_loss: 0.9632 - val_acc: 0.7526
# Epoch 10/10
# 1090/1090 [==============================] - 29s 27ms/step - loss: 1.1125 - acc: 0.6002 - val_loss: 0.9301 - val_acc: 0.7526
